# %%
import pandas as pan
data = pan.read_csv('trees.csv')
data
# Out:
#     Index   "Girth (in)"   "Height (ft)"   "Volume(ft^3)"
# 0       1            8.3              70             10.3
# 1       2            8.6              65             10.3
# 2       3            8.8              63             10.2
# 3       4           10.5              72             16.4
# 4       5           10.7              81             18.8
# 5       6           10.8              83             19.7
# 6       7           11.0              66             15.6
# 7       8           11.0              75             18.2
# 8       9           11.1              80             22.6
# 9      10           11.2              75             19.9
# 10     11           11.3              79             24.2
# 11     12           11.4              76             21.0
# 12     13           11.4              76             21.4
# 13     14           11.7              69             21.3
# 14     15           12.0              75             19.1
# 15     16           12.9              74             22.2
# 16     17           12.9              85             33.8
# 17     18           13.3              86             27.4
# 18     19           13.7              71             25.7
# 19     20           13.8              64             24.9
# 20     21           14.0              78             34.5
# 21     22           14.2              80             31.7
# 22     23           14.5              74             36.3
# 23     24           16.0              72             38.3
# 24     25           16.3              77             42.6
# 25     26           17.3              81             55.4
# 26     27           17.5              82             55.7
# 27     28           17.9              80             58.3
# 28     29           18.0              80             51.5
# 29     30           18.0              80             51.0
# 30     31           20.6              87             77.0

# %%
import pandas as pan
data = pan.read_csv('trees.csv',
                   names = ["I", "Girth", "Height","Volume"])
data
# Out:
#         I          Girth          Height           Volume
# 0   Index   "Girth (in)"   "Height (ft)"   "Volume(ft^3)"
# 1       1            8.3              70             10.3
# 2       2            8.6              65             10.3
# 3       3            8.8              63             10.2
# 4       4           10.5              72             16.4
# 5       5           10.7              81             18.8
# 6       6           10.8              83             19.7
# 7       7           11.0              66             15.6
# 8       8           11.0              75             18.2
# 9       9           11.1              80             22.6
# 10     10           11.2              75             19.9
# 11     11           11.3              79             24.2
# 12     12           11.4              76             21.0
# 13     13           11.4              76             21.4
# 14     14           11.7              69             21.3
# 15     15           12.0              75             19.1
# 16     16           12.9              74             22.2
# 17     17           12.9              85             33.8
# 18     18           13.3              86             27.4
# 19     19           13.7              71             25.7
# 20     20           13.8              64             24.9
# 21     21           14.0              78             34.5
# 22     22           14.2              80             31.7
# 23     23           14.5              74             36.3
# 24     24           16.0              72             38.3
# 25     25           16.3              77             42.6
# 26     26           17.3              81             55.4
# 27     27           17.5              82             55.7
# 28     28           17.9              80             58.3
# 29     29           18.0              80             51.5
# 30     30           18.0              80             51.0
# 31     31           20.6              87             77.0

# %%
import pandas as pan
data = pan.read_csv('trees.csv',
                   names = ["I", "Girth", "Height","Volume"])
del data['I']
data.drop(0, inplace = True)
data
# Out:
#      Girth   Height   Volume
# 1      8.3       70     10.3
# 2      8.6       65     10.3
# 3      8.8       63     10.2
# 4     10.5       72     16.4
# 5     10.7       81     18.8
# 6     10.8       83     19.7
# 7     11.0       66     15.6
# 8     11.0       75     18.2
# 9     11.1       80     22.6
# 10    11.2       75     19.9
# 11    11.3       79     24.2
# 12    11.4       76     21.0
# 13    11.4       76     21.4
# 14    11.7       69     21.3
# 15    12.0       75     19.1
# 16    12.9       74     22.2
# 17    12.9       85     33.8
# 18    13.3       86     27.4
# 19    13.7       71     25.7
# 20    13.8       64     24.9
# 21    14.0       78     34.5
# 22    14.2       80     31.7
# 23    14.5       74     36.3
# 24    16.0       72     38.3
# 25    16.3       77     42.6
# 26    17.3       81     55.4
# 27    17.5       82     55.7
# 28    17.9       80     58.3
# 29    18.0       80     51.5
# 30    18.0       80     51.0
# 31    20.6       87     77.0

# %%
import pandas as pan
data = pan.read_csv('trees.csv',
                   names = ["I", "Girth", "Height","Volume"])
del data['I']
data.drop(0, inplace = True)

data['Girth'] = data['Girth'].astype(float)
data['Girth'] *= 0.0254
data
# Out:
#       Girth   Height   Volume
# 1   0.21082       70     10.3
# 2   0.21844       65     10.3
# 3   0.22352       63     10.2
# 4   0.26670       72     16.4
# 5   0.27178       81     18.8
# 6   0.27432       83     19.7
# 7   0.27940       66     15.6
# 8   0.27940       75     18.2
# 9   0.28194       80     22.6
# 10  0.28448       75     19.9
# 11  0.28702       79     24.2
# 12  0.28956       76     21.0
# 13  0.28956       76     21.4
# 14  0.29718       69     21.3
# 15  0.30480       75     19.1
# 16  0.32766       74     22.2
# 17  0.32766       85     33.8
# 18  0.33782       86     27.4
# 19  0.34798       71     25.7
# 20  0.35052       64     24.9
# 21  0.35560       78     34.5
# 22  0.36068       80     31.7
# 23  0.36830       74     36.3
# 24  0.40640       72     38.3
# 25  0.41402       77     42.6
# 26  0.43942       81     55.4
# 27  0.44450       82     55.7
# 28  0.45466       80     58.3
# 29  0.45720       80     51.5
# 30  0.45720       80     51.0
# 31  0.52324       87     77.0

# %%
import pandas as pan
data = pan.read_csv('trees.csv',
                   names = ["I", "Girth", "Height","Volume"])
del data['I']
data.drop(0, inplace = True)

data['Girth'] = data['Girth'].astype(float)
data['Height'] = data['Height'].astype(float)

data['Girth'] *= 0.0254
data['Height'] *= 0.305
data
# Out:
#       Girth  Height   Volume
# 1   0.21082  21.350     10.3
# 2   0.21844  19.825     10.3
# 3   0.22352  19.215     10.2
# 4   0.26670  21.960     16.4
# 5   0.27178  24.705     18.8
# 6   0.27432  25.315     19.7
# 7   0.27940  20.130     15.6
# 8   0.27940  22.875     18.2
# 9   0.28194  24.400     22.6
# 10  0.28448  22.875     19.9
# 11  0.28702  24.095     24.2
# 12  0.28956  23.180     21.0
# 13  0.28956  23.180     21.4
# 14  0.29718  21.045     21.3
# 15  0.30480  22.875     19.1
# 16  0.32766  22.570     22.2
# 17  0.32766  25.925     33.8
# 18  0.33782  26.230     27.4
# 19  0.34798  21.655     25.7
# 20  0.35052  19.520     24.9
# 21  0.35560  23.790     34.5
# 22  0.36068  24.400     31.7
# 23  0.36830  22.570     36.3
# 24  0.40640  21.960     38.3
# 25  0.41402  23.485     42.6
# 26  0.43942  24.705     55.4
# 27  0.44450  25.010     55.7
# 28  0.45466  24.400     58.3
# 29  0.45720  24.400     51.5
# 30  0.45720  24.400     51.0
# 31  0.52324  26.535     77.0

# %%
import pandas as pan
data = pan.read_csv('trees.csv',
                   names = ["I", "Girth", "Height","Volume"])
del data['I']
data.drop(0, inplace = True) 
data['Girth'] = data['Girth'].astype(float)
data['Height'] = data['Height'].astype(float)
data['Volume'] = data['Volume'].astype(float)

data['Girth'] *= 0.0254
data['Height'] *= 0.305
data['Volume'] *= 0.0283
data
# Out:
#       Girth  Height   Volume
# 1   0.21082  21.350  0.29149
# 2   0.21844  19.825  0.29149
# 3   0.22352  19.215  0.28866
# 4   0.26670  21.960  0.46412
# 5   0.27178  24.705  0.53204
# 6   0.27432  25.315  0.55751
# 7   0.27940  20.130  0.44148
# 8   0.27940  22.875  0.51506
# 9   0.28194  24.400  0.63958
# 10  0.28448  22.875  0.56317
# 11  0.28702  24.095  0.68486
# 12  0.28956  23.180  0.59430
# 13  0.28956  23.180  0.60562
# 14  0.29718  21.045  0.60279
# 15  0.30480  22.875  0.54053
# 16  0.32766  22.570  0.62826
# 17  0.32766  25.925  0.95654
# 18  0.33782  26.230  0.77542
# 19  0.34798  21.655  0.72731
# 20  0.35052  19.520  0.70467
# 21  0.35560  23.790  0.97635
# 22  0.36068  24.400  0.89711
# 23  0.36830  22.570  1.02729
# 24  0.40640  21.960  1.08389
# 25  0.41402  23.485  1.20558
# 26  0.43942  24.705  1.56782
# 27  0.44450  25.010  1.57631
# 28  0.45466  24.400  1.64989
# 29  0.45720  24.400  1.45745
# 30  0.45720  24.400  1.44330
# 31  0.52324  26.535  2.17910

# %%
max_girth = data['Girth'].max()
max_girth
# Out:
# 0.52324

# %%
max_girth = (data['Girth'].round(2)).max()
max_girth
# Out:
# 0.52

# %%
max_girth = (data['Girth'].round(2)).max()
max_height = (data['Height'].round(2)).max()
max_vol = (data['Volume'].round(2)).max()

min_girth = (data['Girth'].round(2)).min()
min_height = (data['Height'].round(2)).min()
min_vol = (data['Volume'].round(2)).min()

avg_girth = round (data['Girth'].mean(), 2)
avg_height = round (data['Height'].mean(), 2)
avg_vol = round (data['Volume'].mean(), 2)

med_girth = (data['Girth'].round(2)).median()
med_height = (data['Height'].round(2)).median()
med_vol = (data['Volume'].round(2)).median()

mod_girth = (data['Girth'].round(2)).mode()
mod_height = (data['Height'].round(2)).mode()
mod_vol = (data['Volume'].round(2)).mode()

# %%
from matplotlib import pyplot as pllt

pllt.plot(data['Girth'])
pllt.title('Girth')
pllt.ylabel('Metres')
# Out:
# Text(0, 0.5, 'Metres')

# %%
from matplotlib import pyplot as pllt

pllt.plot(data['Height'])
pllt.title('Height')
pllt.ylabel('Height')
# Out:
# Text(0, 0.5, 'Height')

# %%
from matplotlib import pyplot as pllt

pllt.plot(data['Volume'])
pllt.title('Volume')
pllt.ylabel('Volume')
# Out:
# Text(0, 0.5, 'Volume')

# %%
from matplotlib import pyplot as pllt

pllt.plot(data['Volume'])
pllt.title('Volume')
pllt.ylabel('Volume')

pllt.plot(data['Girth'])
pllt.title('Girth')
pllt.ylabel('Metres')


pllt.plot(data['Height'])
pllt.title('Height')
pllt.ylabel('Height')
# Out:
# Text(0, 0.5, 'Height')
